# %% [markdown]
# # Extraction

# %%
#Importing dependancies
import pandas as pd
from sqlalchemy import create_engine
from config import gkey
import requests
import json

# %%
#Importing first table
toppings_path ="PizzaWeek.csv"
toppings_df = pd.read_csv(toppings_path)
toppings_df.rename(columns={"Topping": "toppings",
                           "Total": "total",
                           "Male":"male",
                           "Female":"female"}, inplace=True)
toppings_df.rename(columns={'total': 'num_total',
                           'male': 'num_male',
                           'female': 'num_female'}, inplace=True)
toppings_df
# Out:
#           toppings  num_total  num_male  num_female
# 0        Mushrooms         65        63          68
# 1            Onion         62        62          63
# 2              Ham         61        66          56
# 3          Peppers         60        63          57
# 4          Chicken         56        60          52
# 5        Pepperoni         56        66          46
# 6           Tomato         51        49          54
# 7            Bacon         49        56          43
# 8        Pineapple         42        40          44
# 9        Sweetcorn         42        38          46
# 10            Beef         36        47          26
# 11          Olives         33        33          32
# 12        Chillies         31        42          22
# 13       Jalapenos         30        39          21
# 14         Spinach         26        20          32
# 15            Pork         25        34          17
# 16            Tuna         22        23          21
# 17       Anchovies         18        21          15
# 18  Something else         11        12          10

# %%
#Renaming toppings df to match PostGres. 
toppings_df = toppings_df.rename(columns={
    'num_male':'male_total',
    'num_female':'female_total',
    'num_total':'grand_total'
})

# Re-ordering columns.
toppings_df = toppings_df[['toppings',
                           'male_total',
                           'female_total',
                           'grand_total']].copy()

toppings_df
# Out:
#           toppings  male_total  female_total  grand_total
# 0        Mushrooms          63            68           65
# 1            Onion          62            63           62
# 2              Ham          66            56           61
# 3          Peppers          63            57           60
# 4          Chicken          60            52           56
# 5        Pepperoni          66            46           56
# 6           Tomato          49            54           51
# 7            Bacon          56            43           49
# 8        Pineapple          40            44           42
# 9        Sweetcorn          38            46           42
# 10            Beef          47            26           36
# 11          Olives          33            32           33
# 12        Chillies          42            22           31
# 13       Jalapenos          39            21           30
# 14         Spinach          20            32           26
# 15            Pork          34            17           25
# 16            Tuna          23            21           22
# 17       Anchovies          21            15           18
# 18  Something else          12            10           11

# %%
#Reviewing count of each topping/verifying data types
toppings_df.count()
# Out:
# toppings        19
# male_total      19
# female_total    19
# grand_total     19
# dtype: int64

# %%
#Importing second table
restaurants_path="restaurants.csv"
restaurants_df = pd.read_csv(restaurants_path)
restaurants_df.rename(columns= {"menuPageURL":"menupageurl",
                                "postalCode":"postalcode",
                                "priceRangeCurrency":"pricerangecurrency",
                                "priceRangeMin": "pricerangemin",
                                "priceRangeMax": "pricerangemax",
                                "menus.amountMax": "menus_amountmax",
                               "menus.amountMin" : "menus_amountmin",
                               "menus.currency": "menus_currency",
                               "menus.dateSeen": "menus_dateseen",
                               "menus.description": "menus_description",
                               "menus.name": "menus_name"}, inplace=True)
restaurants_df
# Out:
#                         id                                  address  \
# 0     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# ...                    ...                                      ...
# 3505  AVweYUZ0IN2L1WUf4Z9q                               305 Ash St
# 3506  AVweYUZ0IN2L1WUf4Z9q                               305 Ash St
# 3507  AVweZ5SbIN2L1WUf4nWU                         4140 Carlisle Rd
# 3508  AVweZ5SbIN2L1WUf4nWU                         4140 Carlisle Rd
# 3509  AVweZioPIN2L1WUf4kR_              9563 Kings Charter Doctor B
#
#                           categories            city country  \
# 0                        Pizza Place            Bend      US
# 1                        Pizza Place            Bend      US
# 2     American Restaurant,Bar,Bakery     Los Angeles      US
# 3     American Restaurant,Bar,Bakery     Los Angeles      US
# 4     American Restaurant,Bar,Bakery     Los Angeles      US
# ...                              ...             ...     ...
# 3505               Bar and Gastropub  Jefferson City      US
# 3506               Bar and Gastropub  Jefferson City      US
# 3507   Restaurant,Italian Restaurant           Dover      US
# 3508   Restaurant,Italian Restaurant           Dover      US
# 3509                      Restaurant         Ashland      US
#
#                                                    keys   latitude  \
# 0     us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665
# 1     us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665
# 2     us/brentwood/losangeles/148sbarringtonave/-151...  34.064563
# 3     us/brentwood/losangeles/148sbarringtonave/-151...  34.064563
# 4     us/brentwood/losangeles/148sbarringtonave/-151...  34.064563
# ...                                                 ...        ...
# 3505    us/honeycreek/jeffersoncity/305ashst/-735513695  38.568717
# 3506    us/honeycreek/jeffersoncity/305ashst/-735513695  38.568717
# 3507     us/davidsburg/dover/4140carlislerd/-1821521454  39.996444
# 3508     us/davidsburg/dover/4140carlislerd/-1821521454  39.996444
# 3509  us/va/ashland/9563kingscharterdoctorb/-1234885075  37.693160
#
#        longitude menupageurl  menus_amountmax  ...  menus_currency  \
# 0    -121.300797         NaN            22.50  ...             USD
# 1    -121.300797         NaN            18.95  ...             USD
# 2    -118.469017         NaN            12.00  ...             USD
# 3    -118.469017         NaN            13.00  ...             USD
# 4    -118.469017         NaN            13.00  ...             USD
# ...          ...         ...              ...  ...             ...
# 3505  -92.161596         NaN            11.99  ...             USD
# 3506  -92.161596         NaN             9.99  ...             USD
# 3507  -76.845180         NaN             5.00  ...             USD
# 3508  -76.845180         NaN            20.00  ...             USD
# 3509  -77.437440         NaN              NaN  ...             NaN
#
#             menus_dateseen                               menus_description  \
# 0     2016-03-31T02:19:42Z                                             NaN
# 1     2016-03-31T02:19:42Z                                             NaN
# 2     2015-10-23T03:57:26Z                                             NaN
# 3     2015-10-23T03:57:26Z                                             NaN
# 4     2015-10-23T03:57:26Z                Olives, onions, capers, tomatoes
# ...                    ...                                             ...
# 3505  2016-07-06T20:05:49Z                                             NaN
# 3506  2016-07-06T20:05:49Z                                             NaN
# 3507  2015-10-23T01:03:47Z                                             NaN
# 3508  2015-10-23T01:03:47Z                                             NaN
# 3509  2016-08-22T00:00:00Z  ricotta, mozzarella, spinach, garlic, tomatoes
#
#              menus_name                               name postalcode  \
# 0          Bianca Pizza              Little Pizza Paradise      97701
# 1          Cheese Pizza              Little Pizza Paradise      97701
# 2     Pizza, Margherita                      The Brentwood      90049
# 3       Pizza, Mushroom                      The Brentwood      90049
# 4     Pizza, Puttenesca                      The Brentwood      90049
# ...                 ...                                ...        ...
# 3505      Supreme Pizza  Prison Brews Brewery & Restaurant      65101
# 3506   Vegetarian Pizza  Prison Brews Brewery & Restaurant      65101
# 3507         Pita Pizza                     Moonlight Cafe      17315
# 3508    Steak Pizzaiola                     Moonlight Cafe      17315
# 3509        White Pizza                             Guidos      23005
#
#      pricerangecurrency pricerangemin  pricerangemax     province
# 0                   NaN           NaN            NaN           OR
# 1                   NaN           NaN            NaN           OR
# 2                   USD          50.0           55.0    Brentwood
# 3                   USD          50.0           55.0    Brentwood
# 4                   USD          50.0           55.0    Brentwood
# ...                 ...           ...            ...          ...
# 3505                USD          25.0           40.0  Honey Creek
# 3506                USD          25.0           40.0  Honey Creek
# 3507                USD           0.0           30.0   Davidsburg
# 3508                USD           0.0           30.0   Davidsburg
# 3509                USD           0.0           30.0           VA
#
# [3510 rows x 21 columns]

# %%
#Reviewing count of each topping/verifying data types
restaurants_df.count()
# Out:
# id                    3510
# address               3510
# categories            3510
# city                  3510
# country               3510
# keys                  3510
# latitude              3510
# longitude             3510
# menupageurl            610
# menus_amountmax       2948
# menus_amountmin       2948
# menus_currency        2951
# menus_dateseen        3510
# menus_description     1526
# menus_name            3510
# name                  3510
# postalcode            3484
# pricerangecurrency    1557
# pricerangemin         1557
# pricerangemax         1557
# province              3510
# dtype: int64

# %%
#Removing unnecessary columns 
clean_restaurants_df = restaurants_df.drop(columns=['id',
                                                    'keys',
                                                    'menupageurl',
                                                    'menus_currency',
                                                    'menus_dateseen', 
                                                    'menus_description', 
                                                    'pricerangecurrency'])
clean_restaurants_df.rename(columns={'address': 'restaurant_address',
                                    'categories': 'restaurant_type',
                                    'menus_amountmax': 'max_price',
                                    'menus_amountmin': 'min_price',
                                    'menus_currency': 'currency',
                                    'menus_name': 'item_name',
                                    'name': 'restaurant_name',
                                    'postalcode': 'postal_code',
                                    'pricerangemin': 'price_range_min',
                                    'pricerangemax': 'price_range_max',
                                    }, inplace= True)

#Populating null fields with "0"
clean_restaurants_df['max_price'].fillna('0', inplace=True)
clean_restaurants_df['min_price'].fillna('0', inplace=True)
clean_restaurants_df['price_range_min'].fillna('0', inplace=True)
clean_restaurants_df['price_range_max'].fillna('0', inplace=True)
clean_restaurants_df.dropna(inplace=True)
clean_restaurants_df.drop_duplicates()
clean_restaurants_df
# Out:
#                            restaurant_address                 restaurant_type  \
# 0     Cascade Village Mall Across From Target                     Pizza Place
# 1     Cascade Village Mall Across From Target                     Pizza Place
# 2                        148 S Barrington Ave  American Restaurant,Bar,Bakery
# 3                        148 S Barrington Ave  American Restaurant,Bar,Bakery
# 4                        148 S Barrington Ave  American Restaurant,Bar,Bakery
# ...                                       ...                             ...
# 3505                               305 Ash St               Bar and Gastropub
# 3506                               305 Ash St               Bar and Gastropub
# 3507                         4140 Carlisle Rd   Restaurant,Italian Restaurant
# 3508                         4140 Carlisle Rd   Restaurant,Italian Restaurant
# 3509              9563 Kings Charter Doctor B                      Restaurant
#
#                 city country   latitude   longitude max_price min_price  \
# 0               Bend      US  44.102665 -121.300797      22.5      15.5
# 1               Bend      US  44.102665 -121.300797     18.95     18.95
# 2        Los Angeles      US  34.064563 -118.469017        12        12
# 3        Los Angeles      US  34.064563 -118.469017        13        13
# 4        Los Angeles      US  34.064563 -118.469017        13        13
# ...              ...     ...        ...         ...       ...       ...
# 3505  Jefferson City      US  38.568717  -92.161596     11.99     11.99
# 3506  Jefferson City      US  38.568717  -92.161596      9.99      9.99
# 3507           Dover      US  39.996444  -76.845180         5         5
# 3508           Dover      US  39.996444  -76.845180        20        20
# 3509         Ashland      US  37.693160  -77.437440         0         0
#
#               item_name                    restaurant_name postal_code  \
# 0          Bianca Pizza              Little Pizza Paradise       97701
# 1          Cheese Pizza              Little Pizza Paradise       97701
# 2     Pizza, Margherita                      The Brentwood       90049
# 3       Pizza, Mushroom                      The Brentwood       90049
# 4     Pizza, Puttenesca                      The Brentwood       90049
# ...                 ...                                ...         ...
# 3505      Supreme Pizza  Prison Brews Brewery & Restaurant       65101
# 3506   Vegetarian Pizza  Prison Brews Brewery & Restaurant       65101
# 3507         Pita Pizza                     Moonlight Cafe       17315
# 3508    Steak Pizzaiola                     Moonlight Cafe       17315
# 3509        White Pizza                             Guidos       23005
#
#      price_range_min price_range_max     province
# 0                  0               0           OR
# 1                  0               0           OR
# 2                 50              55    Brentwood
# 3                 50              55    Brentwood
# 4                 50              55    Brentwood
# ...              ...             ...          ...
# 3505              25              40  Honey Creek
# 3506              25              40  Honey Creek
# 3507               0              30   Davidsburg
# 3508               0              30   Davidsburg
# 3509               0              30           VA
#
# [3484 rows x 14 columns]

# %% [markdown]
# # Transform

# %%
restaurant_chains_df = pd.DataFrame(clean_restaurants_df['restaurant_name'].value_counts())
restaurant_chains_df.rename(columns={'restaurant_name': 'count'}, inplace=True)
restaurant_chains_df.index.name = 'restaurant_name'
restaurant_chains_df.reset_index(inplace=True)
# restaurant_chains_df.index.name = 'chain_id'
# restaurant_chains_df.reset_index(inplace=True)
restaurant_chains_df
# Out:
#                                       restaurant_name  count
# 0                                  Sicilia's Pizzeria     96
# 1                                    J & G Restaurant     55
# 2                               Casey's General Store     43
# 3                                     The Pizza Joint     36
# 4                                  North End Pizzeria     34
# ..                                                ...    ...
# 922                             First and Last Tavern      1
# 923                                      Jake's Pizza      1
# 924                                  Casa Margarita's      1
# 925                                   Wooden Windmill      1
# 926  Fiala Aesthetics | Metro Orlando Plastic Surgeon      1
#
# [927 rows x 2 columns]

# %%
#How many of each restaurant
unique_restaurants_df = pd.DataFrame(clean_restaurants_df['restaurant_name'].value_counts())
unique_restaurants_df.rename(columns={'restaurant_name': 'count'}, inplace=True)
unique_restaurants_df.index.name = 'restaurant_name'
unique_restaurants_df.reset_index(inplace=True)
unique_restaurants_df.index.name = 'chain_id'
unique_restaurants_df.reset_index(inplace=True)
unique_restaurants_df.drop(['count'], axis=1, inplace=True)
unique_restaurants_df
# Out:
#      chain_id                                   restaurant_name
# 0           0                                Sicilia's Pizzeria
# 1           1                                  J & G Restaurant
# 2           2                             Casey's General Store
# 3           3                                   The Pizza Joint
# 4           4                                North End Pizzeria
# ..        ...                                               ...
# 922       922                             First and Last Tavern
# 923       923                                      Jake's Pizza
# 924       924                                  Casa Margarita's
# 925       925                                   Wooden Windmill
# 926       926  Fiala Aesthetics | Metro Orlando Plastic Surgeon
#
# [927 rows x 2 columns]

# %%
#Location of each restaurant
location_df = clean_restaurants_df[['restaurant_name', 'restaurant_address', 'latitude', 'longitude', 'city', 'province', 'postal_code','country']]
location_df.index.name = 'location_id'

location_df = location_df.drop_duplicates()
location_df = location_df.dropna()
location_df.reset_index(inplace=True)
location_df

#Selecting columns to load. 
location_df = location_df[['location_id','restaurant_name', 'restaurant_address', 'latitude', 'longitude', 'city', 'postal_code','country']].copy()
location_df
# Out:
#      location_id                    restaurant_name  \
# 0              0              Little Pizza Paradise
# 1              2                      The Brentwood
# 2              7              Bravo Pizza Hollywood
# 3             13                        Lucky's Pub
# 4             14                     Roadhouse Cafe
# ..           ...                                ...
# 976         3498                     Rick's Cabaret
# 977         3499           Mighty Mick's Pub & Cafe
# 978         3500  Prison Brews Brewery & Restaurant
# 979         3507                     Moonlight Cafe
# 980         3509                             Guidos
#
#                           restaurant_address   latitude   longitude  \
# 0    Cascade Village Mall Across From Target  44.102665 -121.300797
# 1                       148 S Barrington Ave  34.064563 -118.469017
# 2                        5142 Hollywood Blvd  34.101742 -118.301973
# 3                       801 Saint Emanuel St  29.752479  -95.354164
# 4                               478 South St  41.648278  -70.291345
# ..                                       ...        ...         ...
# 976                        3551 Lafayette Rd  39.817155  -86.228120
# 977      10727 Randolph Saint Crown Point In  41.422509  -87.237723
# 978                               305 Ash St  38.568717  -92.161596
# 979                         4140 Carlisle Rd  39.996444  -76.845180
# 980              9563 Kings Charter Doctor B  37.693160  -77.437440
#
#                city postal_code country
# 0              Bend       97701      US
# 1       Los Angeles       90049      US
# 2       Los Angeles       90027      US
# 3           Houston       77003      US
# 4           Hyannis        2601      US
# ..              ...         ...     ...
# 976    Indianapolis       46222      US
# 977     Crown Point       46307      US
# 978  Jefferson City       65101      US
# 979           Dover       17315      US
# 980         Ashland       23005      US
#
# [981 rows x 8 columns]

# %%
#Merging location_df and unique_restaurants_df
restaurant_location_df = pd.merge(location_df, unique_restaurants_df, how='left', on='restaurant_name')
restaurant_location_df
# Out:
#      location_id                    restaurant_name  \
# 0              0              Little Pizza Paradise
# 1              2                      The Brentwood
# 2              7              Bravo Pizza Hollywood
# 3             13                        Lucky's Pub
# 4             14                     Roadhouse Cafe
# ..           ...                                ...
# 976         3498                     Rick's Cabaret
# 977         3499           Mighty Mick's Pub & Cafe
# 978         3500  Prison Brews Brewery & Restaurant
# 979         3507                     Moonlight Cafe
# 980         3509                             Guidos
#
#                           restaurant_address   latitude   longitude  \
# 0    Cascade Village Mall Across From Target  44.102665 -121.300797
# 1                       148 S Barrington Ave  34.064563 -118.469017
# 2                        5142 Hollywood Blvd  34.101742 -118.301973
# 3                       801 Saint Emanuel St  29.752479  -95.354164
# 4                               478 South St  41.648278  -70.291345
# ..                                       ...        ...         ...
# 976                        3551 Lafayette Rd  39.817155  -86.228120
# 977      10727 Randolph Saint Crown Point In  41.422509  -87.237723
# 978                               305 Ash St  38.568717  -92.161596
# 979                         4140 Carlisle Rd  39.996444  -76.845180
# 980              9563 Kings Charter Doctor B  37.693160  -77.437440
#
#                city postal_code country  chain_id
# 0              Bend       97701      US       425
# 1       Los Angeles       90049      US       225
# 2       Los Angeles       90027      US       146
# 3           Houston       77003      US       897
# 4           Hyannis        2601      US       529
# ..              ...         ...     ...       ...
# 976    Indianapolis       46222      US       582
# 977     Crown Point       46307      US       751
# 978  Jefferson City       65101      US       127
# 979           Dover       17315      US       479
# 980         Ashland       23005      US       611
#
# [981 rows x 9 columns]

# %%
restaurant_location_df = restaurant_location_df[['location_id', 'chain_id', 'restaurant_address', 'city', 'country', 'latitude', 'longitude', 'postal_code']]
restaurant_location_df.rename(columns={'chain_id': 'restaurant_id'}, inplace=True)
restaurant_location_df
# Out:
# C:\Users\monte\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      location_id  restaurant_id                       restaurant_address  \
# 0              0            425  Cascade Village Mall Across From Target
# 1              2            225                     148 S Barrington Ave
# 2              7            146                      5142 Hollywood Blvd
# 3             13            897                     801 Saint Emanuel St
# 4             14            529                             478 South St
# ..           ...            ...                                      ...
# 976         3498            582                        3551 Lafayette Rd
# 977         3499            751      10727 Randolph Saint Crown Point In
# 978         3500            127                               305 Ash St
# 979         3507            479                         4140 Carlisle Rd
# 980         3509            611              9563 Kings Charter Doctor B
#
#                city country   latitude   longitude postal_code
# 0              Bend      US  44.102665 -121.300797       97701
# 1       Los Angeles      US  34.064563 -118.469017       90049
# 2       Los Angeles      US  34.101742 -118.301973       90027
# 3           Houston      US  29.752479  -95.354164       77003
# 4           Hyannis      US  41.648278  -70.291345        2601
# ..              ...     ...        ...         ...         ...
# 976    Indianapolis      US  39.817155  -86.228120       46222
# 977     Crown Point      US  41.422509  -87.237723       46307
# 978  Jefferson City      US  38.568717  -92.161596       65101
# 979           Dover      US  39.996444  -76.845180       17315
# 980         Ashland      US  37.693160  -77.437440       23005
#
# [981 rows x 8 columns]

# %%
#Price ranges
price_range_df = clean_restaurants_df[['restaurant_name', 'price_range_min', 'price_range_max']]
price_range_df = price_range_df.drop_duplicates()
price_range_df.index.name = 'location_id'
price_range_df.reset_index(inplace=True)
price_range_df.drop(columns=['restaurant_name'], axis=1, inplace=True)
price_range_df
# Out:
#      location_id price_range_min price_range_max
# 0              0               0               0
# 1              2              50              55
# 2              7               0               0
# 3             13              25              40
# 4             14               0               0
# ..           ...             ...             ...
# 932         3498               0               0
# 933         3499               0               0
# 934         3500              25              40
# 935         3507               0              30
# 936         3509               0              30
#
# [937 rows x 3 columns]

# %% [markdown]
# ## Load

# %%
# Initiating connection.
rds_connection_string = "postgres:M0neycarlo@localhost:5432/pizza_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Reviewing table names.
engine.table_names()
# Out:
# ['price_range_df',
#  'restaraunt_chains',
#  'restaurant_chains_df',
#  'location_df',
#  'final_pizza_database',
#  'toppings_df']

# %%
#Import toppings_df
toppings_df.to_sql(name='toppings_df', con=engine, if_exists='append', index=False)

# %%
#Verify import is successful.  
pd.read_sql_query('select * from toppings_df', con=engine)
# Out:
#           toppings  male_total  female_total  grand_total
# 0        Mushrooms          63            68           65
# 1            Onion          62            63           62
# 2              Ham          66            56           61
# 3          Peppers          63            57           60
# 4          Chicken          60            52           56
# 5        Pepperoni          66            46           56
# 6           Tomato          49            54           51
# 7            Bacon          56            43           49
# 8        Pineapple          40            44           42
# 9        Sweetcorn          38            46           42
# 10            Beef          47            26           36
# 11          Olives          33            32           33
# 12        Chillies          42            22           31
# 13       Jalapenos          39            21           30
# 14         Spinach          20            32           26
# 15            Pork          34            17           25
# 16            Tuna          23            21           22
# 17       Anchovies          21            15           18
# 18  Something else          12            10           11
# 19       Mushrooms          63            68           65
# 20           Onion          62            63           62
# 21             Ham          66            56           61
# 22         Peppers          63            57           60
# 23         Chicken          60            52           56
# 24       Pepperoni          66            46           56
# 25          Tomato          49            54           51
# 26           Bacon          56            43           49
# 27       Pineapple          40            44           42
# 28       Sweetcorn          38            46           42
# 29            Beef          47            26           36
# 30          Olives          33            32           33
# 31        Chillies          42            22           31
# 32       Jalapenos          39            21           30
# 33         Spinach          20            32           26
# 34            Pork          34            17           25
# 35            Tuna          23            21           22
# 36       Anchovies          21            15           18
# 37  Something else          12            10           11

# %%
#Import restaraunt_chains_df 
restaurant_chains_df.to_sql(name='restaurant_chains_df', con=engine, if_exists='append', index=False)

# %%
#Ensure import is successful 
pd.read_sql_query('select * from restaurant_chains_df', con=engine)
# Out:
#                                        restaurant_name  count
# 0                                   Sicilia's Pizzeria     96
# 1                                     J & G Restaurant     55
# 2                                Casey's General Store     43
# 3                                      The Pizza Joint     36
# 4                                   North End Pizzeria     34
# ...                                                ...    ...
# 1849                             First and Last Tavern      1
# 1850                                      Jake's Pizza      1
# 1851                                  Casa Margarita's      1
# 1852                                   Wooden Windmill      1
# 1853  Fiala Aesthetics | Metro Orlando Plastic Surgeon      1
#
# [1854 rows x 2 columns]

# %%
#Import location_df
location_df.to_sql(name='location_df', con=engine, if_exists='append', index=False)

# %%
#Ensure import is successful 
pd.read_sql_query('select * from location_df', con=engine)
# Out:
#       location_id                    restaurant_name  \
# 0             NaN              Little Pizza Paradise
# 1             NaN                      The Brentwood
# 2             NaN              Bravo Pizza Hollywood
# 3             NaN                        Lucky's Pub
# 4             NaN                     Roadhouse Cafe
# ...           ...                                ...
# 2938       3498.0                     Rick's Cabaret
# 2939       3499.0           Mighty Mick's Pub & Cafe
# 2940       3500.0  Prison Brews Brewery & Restaurant
# 2941       3507.0                     Moonlight Cafe
# 2942       3509.0                             Guidos
#
#                            restaurant_address   latitude   longitude  \
# 0     Cascade Village Mall Across From Target  44.102665 -121.300797
# 1                        148 S Barrington Ave  34.064563 -118.469017
# 2                         5142 Hollywood Blvd  34.101742 -118.301973
# 3                        801 Saint Emanuel St  29.752479  -95.354164
# 4                                478 South St  41.648278  -70.291345
# ...                                       ...        ...         ...
# 2938                        3551 Lafayette Rd  39.817155  -86.228120
# 2939      10727 Randolph Saint Crown Point In  41.422509  -87.237723
# 2940                               305 Ash St  38.568717  -92.161596
# 2941                         4140 Carlisle Rd  39.996444  -76.845180
# 2942              9563 Kings Charter Doctor B  37.693160  -77.437440
#
#                 city postal_code country
# 0               Bend       97701      US
# 1        Los Angeles       90049      US
# 2        Los Angeles       90027      US
# 3            Houston       77003      US
# 4            Hyannis        2601      US
# ...              ...         ...     ...
# 2938    Indianapolis       46222      US
# 2939     Crown Point       46307      US
# 2940  Jefferson City       65101      US
# 2941           Dover       17315      US
# 2942         Ashland       23005      US
#
# [2943 rows x 8 columns]

# %%
#Import price_range_df
price_range_df.to_sql(name='price_range_df', con=engine, if_exists='append', index=False)

# %%
#Ensure import is successful 
pd.read_sql_query('select * from price_range_df', con=engine)
# Out:
#       location_id  price_range_min  price_range_max
# 0               0                0                0
# 1               2               50               55
# 2               7                0                0
# 3              13               25               40
# 4              14                0                0
# ...           ...              ...              ...
# 1869         3498                0                0
# 1870         3499                0                0
# 1871         3500               25               40
# 1872         3507                0               30
# 1873         3509                0               30
#
# [1874 rows x 3 columns]

# %%
#Review finalized database
pd.read_sql_query('select * from final_pizza_database', con=engine)
# Out:
#      Location ID                    Restaurant Name  \
# 0              0              Little Pizza Paradise
# 1              2                      The Brentwood
# 2              7              Bravo Pizza Hollywood
# 3             13                        Lucky's Pub
# 4             14                     Roadhouse Cafe
# ..           ...                                ...
# 932         3498                     Rick's Cabaret
# 933         3499           Mighty Mick's Pub & Cafe
# 934         3500  Prison Brews Brewery & Restaurant
# 935         3507                     Moonlight Cafe
# 936         3509                             Guidos
#
#                           Restaurant Address  Rest. Chain Count   Latitude  \
# 0    Cascade Village Mall Across From Target                  2  44.102665
# 1                       148 S Barrington Ave                  5  34.064563
# 2                        5142 Hollywood Blvd                  6  34.101742
# 3                       801 Saint Emanuel St                  1  29.752479
# 4                               478 South St                  2  41.648278
# ..                                       ...                ...        ...
# 932                        3551 Lafayette Rd                  1  39.817155
# 933      10727 Randolph Saint Crown Point In                  1  41.422509
# 934                               305 Ash St                  7  38.568717
# 935                         4140 Carlisle Rd                  2  39.996444
# 936              9563 Kings Charter Doctor B                  1  37.693160
#
#       Longitude            City Postal Code Country  Min Price Range  \
# 0   -121.300797            Bend       97701      US                0
# 1   -118.469017     Los Angeles       90049      US               50
# 2   -118.301973     Los Angeles       90027      US                0
# 3    -95.354164         Houston       77003      US               25
# 4    -70.291345         Hyannis        2601      US                0
# ..          ...             ...         ...     ...              ...
# 932  -86.228120    Indianapolis       46222      US                0
# 933  -87.237723     Crown Point       46307      US                0
# 934  -92.161596  Jefferson City       65101      US               25
# 935  -76.845180           Dover       17315      US                0
# 936  -77.437440         Ashland       23005      US                0
#
#      Max Price Range
# 0                  0
# 1                 55
# 2                  0
# 3                 40
# 4                  0
# ..               ...
# 932                0
# 933                0
# 934               40
# 935               30
# 936               30
#
# [937 rows x 11 columns]

# %% [markdown]
# ## Final Database

# %%
## FIRST TABLE: Final pizza database with key information regarding restaraunts.
pd.read_sql_query('select * from final_pizza_database', con=engine)
# Out:
#      Location ID                    Restaurant Name  \
# 0              0              Little Pizza Paradise
# 1              2                      The Brentwood
# 2              7              Bravo Pizza Hollywood
# 3             13                        Lucky's Pub
# 4             14                     Roadhouse Cafe
# ..           ...                                ...
# 932         3498                     Rick's Cabaret
# 933         3499           Mighty Mick's Pub & Cafe
# 934         3500  Prison Brews Brewery & Restaurant
# 935         3507                     Moonlight Cafe
# 936         3509                             Guidos
#
#                           Restaurant Address  Rest. Chain Count   Latitude  \
# 0    Cascade Village Mall Across From Target                  2  44.102665
# 1                       148 S Barrington Ave                  5  34.064563
# 2                        5142 Hollywood Blvd                  6  34.101742
# 3                       801 Saint Emanuel St                  1  29.752479
# 4                               478 South St                  2  41.648278
# ..                                       ...                ...        ...
# 932                        3551 Lafayette Rd                  1  39.817155
# 933      10727 Randolph Saint Crown Point In                  1  41.422509
# 934                               305 Ash St                  7  38.568717
# 935                         4140 Carlisle Rd                  2  39.996444
# 936              9563 Kings Charter Doctor B                  1  37.693160
#
#       Longitude            City Postal Code Country  Min Price Range  \
# 0   -121.300797            Bend       97701      US                0
# 1   -118.469017     Los Angeles       90049      US               50
# 2   -118.301973     Los Angeles       90027      US                0
# 3    -95.354164         Houston       77003      US               25
# 4    -70.291345         Hyannis        2601      US                0
# ..          ...             ...         ...     ...              ...
# 932  -86.228120    Indianapolis       46222      US                0
# 933  -87.237723     Crown Point       46307      US                0
# 934  -92.161596  Jefferson City       65101      US               25
# 935  -76.845180           Dover       17315      US                0
# 936  -77.437440         Ashland       23005      US                0
#
#      Max Price Range
# 0                  0
# 1                 55
# 2                  0
# 3                 40
# 4                  0
# ..               ...
# 932                0
# 933                0
# 934               40
# 935               30
# 936               30
#
# [937 rows x 11 columns]

# %%
## SECOND TABLE: Supplementary database with information regarding preferred toppings. 
pd.read_sql_query('select * from toppings_df', con=engine)
# Out:
#           toppings  male_total  female_total  grand_total
# 0        Mushrooms          63            68           65
# 1            Onion          62            63           62
# 2              Ham          66            56           61
# 3          Peppers          63            57           60
# 4          Chicken          60            52           56
# 5        Pepperoni          66            46           56
# 6           Tomato          49            54           51
# 7            Bacon          56            43           49
# 8        Pineapple          40            44           42
# 9        Sweetcorn          38            46           42
# 10            Beef          47            26           36
# 11          Olives          33            32           33
# 12        Chillies          42            22           31
# 13       Jalapenos          39            21           30
# 14         Spinach          20            32           26
# 15            Pork          34            17           25
# 16            Tuna          23            21           22
# 17       Anchovies          21            15           18
# 18  Something else          12            10           11
# 19       Mushrooms          63            68           65
# 20           Onion          62            63           62
# 21             Ham          66            56           61
# 22         Peppers          63            57           60
# 23         Chicken          60            52           56
# 24       Pepperoni          66            46           56
# 25          Tomato          49            54           51
# 26           Bacon          56            43           49
# 27       Pineapple          40            44           42
# 28       Sweetcorn          38            46           42
# 29            Beef          47            26           36
# 30          Olives          33            32           33
# 31        Chillies          42            22           31
# 32       Jalapenos          39            21           30
# 33         Spinach          20            32           26
# 34            Pork          34            17           25
# 35            Tuna          23            21           22
# 36       Anchovies          21            15           18
# 37  Something else          12            10           11

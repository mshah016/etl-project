# %%
import pandas as pd
from sqlalchemy import create_engine
from config import gkey
import requests
import json

# %% [markdown]
# ## Extract

# %%
# Source 1
toppings_path="PizzaWeek.csv"
toppings_df = pd.read_csv(toppings_path)
toppings_df.rename(columns={"Topping": "toppings",
                           "Total": "total",
                           "Male":"male",
                           "Female":"female"}, inplace=True)
toppings_df.set_index('toppings', inplace=True)
toppings_df.rename(columns={'total': 'num_total',
                           'male': 'num_male',
                           'female': 'num_female'}, inplace=True)
toppings_df
# Out:
#                 num_total  num_male  num_female
# toppings
# Mushrooms              65        63          68
# Onion                  62        62          63
# Ham                    61        66          56
# Peppers                60        63          57
# Chicken                56        60          52
# Pepperoni              56        66          46
# Tomato                 51        49          54
# Bacon                  49        56          43
# Pineapple              42        40          44
# Sweetcorn              42        38          46
# Beef                   36        47          26
# Olives                 33        33          32
# Chillies               31        42          22
# Jalapenos              30        39          21
# Spinach                26        20          32
# Pork                   25        34          17
# Tuna                   22        23          21
# Anchovies              18        21          15
# Something else         11        12          10

# %%
toppings_df.count()
# Out:
# num_total     19
# num_male      19
# num_female    19
# dtype: int64

# %%
# Source 2
restaurants_path="restaurants.csv"
restaurants_df = pd.read_csv(restaurants_path)
restaurants_df.rename(columns= {"menuPageURL":"menupageurl",
                                "postalCode":"postalcode",
                                "priceRangeCurrency":"pricerangecurrency",
                                "priceRangeMin": "pricerangemin",
                                "priceRangeMax": "pricerangemax",
                                "menus.amountMax": "menus_amountmax",
                               "menus.amountMin" : "menus_amountmin",
                               "menus.currency": "menus_currency",
                               "menus.dateSeen": "menus_dateseen",
                               "menus.description": "menus_description",
                               "menus.name": "menus_name"}, inplace=True)
restaurants_df
# Out:
#                         id                                  address  \
# 0     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1     AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4     AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# ...                    ...                                      ...
# 3505  AVweYUZ0IN2L1WUf4Z9q                               305 Ash St
# 3506  AVweYUZ0IN2L1WUf4Z9q                               305 Ash St
# 3507  AVweZ5SbIN2L1WUf4nWU                         4140 Carlisle Rd
# 3508  AVweZ5SbIN2L1WUf4nWU                         4140 Carlisle Rd
# 3509  AVweZioPIN2L1WUf4kR_              9563 Kings Charter Doctor B
#
#                           categories            city country  \
# 0                        Pizza Place            Bend      US
# 1                        Pizza Place            Bend      US
# 2     American Restaurant,Bar,Bakery     Los Angeles      US
# 3     American Restaurant,Bar,Bakery     Los Angeles      US
# 4     American Restaurant,Bar,Bakery     Los Angeles      US
# ...                              ...             ...     ...
# 3505               Bar and Gastropub  Jefferson City      US
# 3506               Bar and Gastropub  Jefferson City      US
# 3507   Restaurant,Italian Restaurant           Dover      US
# 3508   Restaurant,Italian Restaurant           Dover      US
# 3509                      Restaurant         Ashland      US
#
#                                                    keys   latitude  \
# 0     us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665
# 1     us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665
# 2     us/brentwood/losangeles/148sbarringtonave/-151...  34.064563
# 3     us/brentwood/losangeles/148sbarringtonave/-151...  34.064563
# 4     us/brentwood/losangeles/148sbarringtonave/-151...  34.064563
# ...                                                 ...        ...
# 3505    us/honeycreek/jeffersoncity/305ashst/-735513695  38.568717
# 3506    us/honeycreek/jeffersoncity/305ashst/-735513695  38.568717
# 3507     us/davidsburg/dover/4140carlislerd/-1821521454  39.996444
# 3508     us/davidsburg/dover/4140carlislerd/-1821521454  39.996444
# 3509  us/va/ashland/9563kingscharterdoctorb/-1234885075  37.693160
#
#        longitude menupageurl  menus_amountmax  ...  menus_currency  \
# 0    -121.300797         NaN            22.50  ...             USD
# 1    -121.300797         NaN            18.95  ...             USD
# 2    -118.469017         NaN            12.00  ...             USD
# 3    -118.469017         NaN            13.00  ...             USD
# 4    -118.469017         NaN            13.00  ...             USD
# ...          ...         ...              ...  ...             ...
# 3505  -92.161596         NaN            11.99  ...             USD
# 3506  -92.161596         NaN             9.99  ...             USD
# 3507  -76.845180         NaN             5.00  ...             USD
# 3508  -76.845180         NaN            20.00  ...             USD
# 3509  -77.437440         NaN              NaN  ...             NaN
#
#             menus_dateseen                               menus_description  \
# 0     2016-03-31T02:19:42Z                                             NaN
# 1     2016-03-31T02:19:42Z                                             NaN
# 2     2015-10-23T03:57:26Z                                             NaN
# 3     2015-10-23T03:57:26Z                                             NaN
# 4     2015-10-23T03:57:26Z                Olives, onions, capers, tomatoes
# ...                    ...                                             ...
# 3505  2016-07-06T20:05:49Z                                             NaN
# 3506  2016-07-06T20:05:49Z                                             NaN
# 3507  2015-10-23T01:03:47Z                                             NaN
# 3508  2015-10-23T01:03:47Z                                             NaN
# 3509  2016-08-22T00:00:00Z  ricotta, mozzarella, spinach, garlic, tomatoes
#
#              menus_name                               name postalcode  \
# 0          Bianca Pizza              Little Pizza Paradise      97701
# 1          Cheese Pizza              Little Pizza Paradise      97701
# 2     Pizza, Margherita                      The Brentwood      90049
# 3       Pizza, Mushroom                      The Brentwood      90049
# 4     Pizza, Puttenesca                      The Brentwood      90049
# ...                 ...                                ...        ...
# 3505      Supreme Pizza  Prison Brews Brewery & Restaurant      65101
# 3506   Vegetarian Pizza  Prison Brews Brewery & Restaurant      65101
# 3507         Pita Pizza                     Moonlight Cafe      17315
# 3508    Steak Pizzaiola                     Moonlight Cafe      17315
# 3509        White Pizza                             Guidos      23005
#
#      pricerangecurrency pricerangemin  pricerangemax     province
# 0                   NaN           NaN            NaN           OR
# 1                   NaN           NaN            NaN           OR
# 2                   USD          50.0           55.0    Brentwood
# 3                   USD          50.0           55.0    Brentwood
# 4                   USD          50.0           55.0    Brentwood
# ...                 ...           ...            ...          ...
# 3505                USD          25.0           40.0  Honey Creek
# 3506                USD          25.0           40.0  Honey Creek
# 3507                USD           0.0           30.0   Davidsburg
# 3508                USD           0.0           30.0   Davidsburg
# 3509                USD           0.0           30.0           VA
#
# [3510 rows x 21 columns]

# %%
restaurants_df.count()
# Out:
# id                    3510
# address               3510
# categories            3510
# city                  3510
# country               3510
# keys                  3510
# latitude              3510
# longitude             3510
# menupageurl            610
# menus_amountmax       2948
# menus_amountmin       2948
# menus_currency        2951
# menus_dateseen        3510
# menus_description     1526
# menus_name            3510
# name                  3510
# postalcode            3484
# pricerangecurrency    1557
# pricerangemin         1557
# pricerangemax         1557
# province              3510
# dtype: int64

# %%
# remove unnecessary columns 
clean_restaurants_df = restaurants_df.drop(columns=['id',
                                                    'keys',
                                                    'menupageurl',
                                                    'menus_currency',
                                                    'menus_dateseen', 
                                                    'menus_description', 
                                                    'pricerangecurrency'])
clean_restaurants_df.rename(columns={'address': 'restaurant_address',
                                    'categories': 'restaurant_type',
                                    'menus_amountmax': 'max_price',
                                    'menus_amountmin': 'min_price',
                                    'menus_currency': 'currency',
                                    'menus_name': 'item_name',
                                    'name': 'restaurant_name',
                                    'postalcode': 'postal_code',
                                    'pricerangemin': 'price_range_min',
                                    'pricerangemax': 'price_range_max',
                                    }, inplace= True)

clean_restaurants_df['max_price'].fillna('0', inplace=True)
clean_restaurants_df['min_price'].fillna('0', inplace=True)
clean_restaurants_df['price_range_min'].fillna('0', inplace=True)
clean_restaurants_df['price_range_max'].fillna('0', inplace=True)
clean_restaurants_df.dropna(inplace=True)
clean_restaurants_df.drop_duplicates()
clean_restaurants_df
# Out:
#                            restaurant_address                 restaurant_type  \
# 0     Cascade Village Mall Across From Target                     Pizza Place
# 1     Cascade Village Mall Across From Target                     Pizza Place
# 2                        148 S Barrington Ave  American Restaurant,Bar,Bakery
# 3                        148 S Barrington Ave  American Restaurant,Bar,Bakery
# 4                        148 S Barrington Ave  American Restaurant,Bar,Bakery
# ...                                       ...                             ...
# 3505                               305 Ash St               Bar and Gastropub
# 3506                               305 Ash St               Bar and Gastropub
# 3507                         4140 Carlisle Rd   Restaurant,Italian Restaurant
# 3508                         4140 Carlisle Rd   Restaurant,Italian Restaurant
# 3509              9563 Kings Charter Doctor B                      Restaurant
#
#                 city country   latitude   longitude max_price min_price  \
# 0               Bend      US  44.102665 -121.300797      22.5      15.5
# 1               Bend      US  44.102665 -121.300797     18.95     18.95
# 2        Los Angeles      US  34.064563 -118.469017        12        12
# 3        Los Angeles      US  34.064563 -118.469017        13        13
# 4        Los Angeles      US  34.064563 -118.469017        13        13
# ...              ...     ...        ...         ...       ...       ...
# 3505  Jefferson City      US  38.568717  -92.161596     11.99     11.99
# 3506  Jefferson City      US  38.568717  -92.161596      9.99      9.99
# 3507           Dover      US  39.996444  -76.845180         5         5
# 3508           Dover      US  39.996444  -76.845180        20        20
# 3509         Ashland      US  37.693160  -77.437440         0         0
#
#               item_name                    restaurant_name postal_code  \
# 0          Bianca Pizza              Little Pizza Paradise       97701
# 1          Cheese Pizza              Little Pizza Paradise       97701
# 2     Pizza, Margherita                      The Brentwood       90049
# 3       Pizza, Mushroom                      The Brentwood       90049
# 4     Pizza, Puttenesca                      The Brentwood       90049
# ...                 ...                                ...         ...
# 3505      Supreme Pizza  Prison Brews Brewery & Restaurant       65101
# 3506   Vegetarian Pizza  Prison Brews Brewery & Restaurant       65101
# 3507         Pita Pizza                     Moonlight Cafe       17315
# 3508    Steak Pizzaiola                     Moonlight Cafe       17315
# 3509        White Pizza                             Guidos       23005
#
#      price_range_min price_range_max     province
# 0                  0               0           OR
# 1                  0               0           OR
# 2                 50              55    Brentwood
# 3                 50              55    Brentwood
# 4                 50              55    Brentwood
# ...              ...             ...          ...
# 3505              25              40  Honey Creek
# 3506              25              40  Honey Creek
# 3507               0              30   Davidsburg
# 3508               0              30   Davidsburg
# 3509               0              30           VA
#
# [3484 rows x 14 columns]

# %%
def get_state_abbr(postal_codes):
    for code in postal_codes:
        base_url = "https://maps.googleapis.com/maps/api/geocode/json?"
        address_url = f'{base_url}address={code}&key={gkey}&sensor=true'
        zip_data = requests.get(address_url, verify=True).json()
        try:
            address_components = zip_data['results'][0]['address_components']
            for component in address_components:
                types = component['types']
                if 'administrative_area_level_1' in types:
                    output = component['short_name']
                else:
                    output = "None"
        except:
            output = "None"
        
    return output

# %%
for index, row in clean_restaurants_df.iterrows():
    if len(row['province']) != 2:
        replacement = get_state_abbr(row['postal_code'])
        row['province'].replace(row['province'], replacement)
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1638                     if errno != 0:
# -> 1639                         raise SysCallError(errno, errorcode.get(errno))
#    1640                 raise SysCallError(-1, "Unexpected EOF")
#
# SysCallError: (10051, 'WSAENETUNREACH')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     346         if HAS_SNI and server_hostname is not None:
# --> 347             return context.wrap_socket(sock, server_hostname=server_hostname)
#     348
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     461             except OpenSSL.SSL.Error as e:
# --> 462                 raise ssl.SSLError('bad handshake: %r' % e)
#     463             break
#
# SSLError: ("bad handshake: SysCallError(10051, 'WSAENETUNREACH')",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=0&key=AIzaSyDcapwgCoMCf02_Z5egOEw_fAx0HhlXf4M&sensor=true (Caused by SSLError(SSLError("bad handshake: SysCallError(10051, 'WSAENETUNREACH')")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-11-602ad6a06384> in <module>
#       1 for index, row in clean_restaurants_df.iterrows():
#       2     if len(row['province']) != 2:
# ----> 3         replacement = get_state_abbr(row['postal_code'])
#       4         row['province'].replace(row['province'], replacement)
#
# <ipython-input-10-9bdebf36baab> in get_state_abbr(postal_codes)
#       3         base_url = "https://maps.googleapis.com/maps/api/geocode/json?"
#       4         address_url = f'{base_url}address={code}&key={gkey}&sensor=true'
# ----> 5         zip_data = requests.get(address_url, verify=True).json()
#       6         try:
#       7             address_components = zip_data['results'][0]['address_components']
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=0&key=AIzaSyDcapwgCoMCf02_Z5egOEw_fAx0HhlXf4M&sensor=true (Caused by SSLError(SSLError("bad handshake: SysCallError(10051, 'WSAENETUNREACH')")))

# %% [markdown]
# ## Transform

# %%
restaurant_chains_df = pd.DataFrame(clean_restaurants_df['restaurant_name'].value_counts())
restaurant_chains_df.rename(columns={'restaurant_name': 'count'}, inplace=True)
restaurant_chains_df.index.name = 'restaurant_name'
restaurant_chains_df.reset_index(inplace=True)
restaurant_chains_df.index.name = 'chain_id'
restaurant_chains_df.reset_index(inplace=True)
restaurant_chains_df
# Out:
#      chain_id        restaurant_name  count
# 0           0     Sicilia's Pizzeria     96
# 1           1       J & G Restaurant     55
# 2           2  Casey's General Store     43
# 3           3        The Pizza Joint     36
# 4           4     North End Pizzeria     34
# ..        ...                    ...    ...
# 922       922                 Spagio      1
# 923       923      Rosangela's Pizza      1
# 924       924         Paradise Lanes      1
# 925       925           Holy Cannoli      1
# 926       926             The Bistro      1
#
# [927 rows x 3 columns]

# %%
#how many of each restaurant
unique_restaurants_df = pd.DataFrame(clean_restaurants_df['restaurant_name'].value_counts())
unique_restaurants_df.rename(columns={'restaurant_name': 'count'}, inplace=True)
unique_restaurants_df.index.name = 'restaurant_name'
unique_restaurants_df.reset_index(inplace=True)
unique_restaurants_df.index.name = 'chain_id'
unique_restaurants_df.reset_index(inplace=True)
unique_restaurants_df.drop(['count'], axis=1, inplace=True)
unique_restaurants_df
# Out:
#      chain_id        restaurant_name
# 0           0     Sicilia's Pizzeria
# 1           1       J & G Restaurant
# 2           2  Casey's General Store
# 3           3        The Pizza Joint
# 4           4     North End Pizzeria
# ..        ...                    ...
# 922       922                 Spagio
# 923       923      Rosangela's Pizza
# 924       924         Paradise Lanes
# 925       925           Holy Cannoli
# 926       926             The Bistro
#
# [927 rows x 2 columns]

# %%
#location of each restaurant
location_df = clean_restaurants_df[['restaurant_address', 'city', 'country', 'latitude', 'longitude', 'restaurant_name', 'postal_code', 'province']]
location_df.index.name = 'location_id'

location_df = location_df.drop_duplicates()
location_df = location_df.dropna()
location_df.reset_index(inplace=True)
location_df
# Out:
#      location_id                       restaurant_address            city  \
# 0              0  Cascade Village Mall Across From Target            Bend
# 1              2                     148 S Barrington Ave     Los Angeles
# 2              7                      5142 Hollywood Blvd     Los Angeles
# 3             13                     801 Saint Emanuel St         Houston
# 4             14                             478 South St         Hyannis
# ..           ...                                      ...             ...
# 976         3498                        3551 Lafayette Rd    Indianapolis
# 977         3499      10727 Randolph Saint Crown Point In     Crown Point
# 978         3500                               305 Ash St  Jefferson City
# 979         3507                         4140 Carlisle Rd           Dover
# 980         3509              9563 Kings Charter Doctor B         Ashland
#
#     country   latitude   longitude                    restaurant_name  \
# 0        US  44.102665 -121.300797              Little Pizza Paradise
# 1        US  34.064563 -118.469017                      The Brentwood
# 2        US  34.101742 -118.301973              Bravo Pizza Hollywood
# 3        US  29.752479  -95.354164                        Lucky's Pub
# 4        US  41.648278  -70.291345                     Roadhouse Cafe
# ..      ...        ...         ...                                ...
# 976      US  39.817155  -86.228120                     Rick's Cabaret
# 977      US  41.422509  -87.237723           Mighty Mick's Pub & Cafe
# 978      US  38.568717  -92.161596  Prison Brews Brewery & Restaurant
# 979      US  39.996444  -76.845180                     Moonlight Cafe
# 980      US  37.693160  -77.437440                             Guidos
#
#     postal_code     province
# 0         97701           OR
# 1         90049    Brentwood
# 2         90027    Los Feliz
# 3         77003           TX
# 4          2601           MA
# ..          ...          ...
# 976       46222           IN
# 977       46307       Palmer
# 978       65101  Honey Creek
# 979       17315   Davidsburg
# 980       23005           VA
#
# [981 rows x 9 columns]

# %%
restaurant_location_df = pd.merge(location_df, unique_restaurants_df, how='left', on='restaurant_name')
restaurant_location_df
# Out:
#      location_id                       restaurant_address            city  \
# 0              0  Cascade Village Mall Across From Target            Bend
# 1              2                     148 S Barrington Ave     Los Angeles
# 2              7                      5142 Hollywood Blvd     Los Angeles
# 3             13                     801 Saint Emanuel St         Houston
# 4             14                             478 South St         Hyannis
# ..           ...                                      ...             ...
# 976         3498                        3551 Lafayette Rd    Indianapolis
# 977         3499      10727 Randolph Saint Crown Point In     Crown Point
# 978         3500                               305 Ash St  Jefferson City
# 979         3507                         4140 Carlisle Rd           Dover
# 980         3509              9563 Kings Charter Doctor B         Ashland
#
#     country   latitude   longitude                    restaurant_name  \
# 0        US  44.102665 -121.300797              Little Pizza Paradise
# 1        US  34.064563 -118.469017                      The Brentwood
# 2        US  34.101742 -118.301973              Bravo Pizza Hollywood
# 3        US  29.752479  -95.354164                        Lucky's Pub
# 4        US  41.648278  -70.291345                     Roadhouse Cafe
# ..      ...        ...         ...                                ...
# 976      US  39.817155  -86.228120                     Rick's Cabaret
# 977      US  41.422509  -87.237723           Mighty Mick's Pub & Cafe
# 978      US  38.568717  -92.161596  Prison Brews Brewery & Restaurant
# 979      US  39.996444  -76.845180                     Moonlight Cafe
# 980      US  37.693160  -77.437440                             Guidos
#
#     postal_code     province  chain_id
# 0         97701           OR       528
# 1         90049    Brentwood       225
# 2         90027    Los Feliz       158
# 3         77003           TX       875
# 4          2601           MA       433
# ..          ...          ...       ...
# 976       46222           IN       844
# 977       46307       Palmer       593
# 978       65101  Honey Creek       131
# 979       17315   Davidsburg       472
# 980       23005           VA       669
#
# [981 rows x 10 columns]

# %%
restaurant_location_df = restaurant_location_df[['location_id', 'chain_id', 'restaurant_address', 'city', 'country', 'latitude', 'longitude', 'postal_code', 'province']]
restaurant_location_df.rename(columns={'chain_id': 'restaurant_id'}, inplace=True)
restaurant_location_df
# Out:
# C:\Users\meera\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#      location_id  restaurant_id                       restaurant_address  \
# 0              0            528  Cascade Village Mall Across From Target
# 1              2            225                     148 S Barrington Ave
# 2              7            158                      5142 Hollywood Blvd
# 3             13            875                     801 Saint Emanuel St
# 4             14            433                             478 South St
# ..           ...            ...                                      ...
# 976         3498            844                        3551 Lafayette Rd
# 977         3499            593      10727 Randolph Saint Crown Point In
# 978         3500            131                               305 Ash St
# 979         3507            472                         4140 Carlisle Rd
# 980         3509            669              9563 Kings Charter Doctor B
#
#                city country   latitude   longitude postal_code     province
# 0              Bend      US  44.102665 -121.300797       97701           OR
# 1       Los Angeles      US  34.064563 -118.469017       90049    Brentwood
# 2       Los Angeles      US  34.101742 -118.301973       90027    Los Feliz
# 3           Houston      US  29.752479  -95.354164       77003           TX
# 4           Hyannis      US  41.648278  -70.291345        2601           MA
# ..              ...     ...        ...         ...         ...          ...
# 976    Indianapolis      US  39.817155  -86.228120       46222           IN
# 977     Crown Point      US  41.422509  -87.237723       46307       Palmer
# 978  Jefferson City      US  38.568717  -92.161596       65101  Honey Creek
# 979           Dover      US  39.996444  -76.845180       17315   Davidsburg
# 980         Ashland      US  37.693160  -77.437440       23005           VA
#
# [981 rows x 9 columns]

# %%
#price 
price_range_df = clean_restaurants_df[['restaurant_name', 'price_range_min', 'price_range_max']]
price_range_df = price_range_df.drop_duplicates()
price_range_df.index.name = 'location_id'
price_range_df.reset_index(inplace=True)
price_range_df.drop(columns=['restaurant_name'], axis=1, inplace=True)
price_range_df
# Out:
#      location_id price_range_min price_range_max
# 0              0               0               0
# 1              2              50              55
# 2              7               0               0
# 3             13              25              40
# 4             14               0               0
# ..           ...             ...             ...
# 932         3498               0               0
# 933         3499               0               0
# 934         3500              25              40
# 935         3507               0              30
# 936         3509               0              30
#
# [937 rows x 3 columns]

# %% [markdown]
# ## Load

# %%
engine_string = (f'postgresql://postgres:postgres@localhost:5432/pizza_db')
engine = create_engine(engine_string)

# %%
engine.table_names()
# Out:
# ['toppings', 'restaurant_chains', 'restaurant_location', 'price_range']

# %%
# this one works
toppings_df.to_sql(name='toppings', con=engine, if_exists='append', index=False)

# %%
# this one works
restaurant_chains_df.to_sql(name='restaurant_chains', con=engine, if_exists='append', index=False)

# %%
price_range_df.to_sql(name='price_range', con=engine, if_exists='append', index=False)

# %%
restaurant_location_df.to_sql(name='restaurant_location', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# ForeignKeyViolation: insert or update on table "restaurant_location" violates foreign key constraint "location_id"
# DETAIL:  Key (location_id)=(483) is not present in table "price_range".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-89-ceb774f4bb4f> in <module>
# ----> 1 restaurant_location_df.to_sql(name='restaurant_location', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1318         )
#    1319         table.create()
# -> 1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#    1322             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     754
#     755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 756                 exec_insert(conn, keys, chunk_iter)
#     757
#     758     def _query_iterator(
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         """
#     669         data = [dict(zip(keys, row)) for row in data_iter]
# --> 670         conn.execute(self.table.insert(), data)
#     671
#     672     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                 if not evt_handled:
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#    1231             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "restaurant_location" violates foreign key constraint "location_id"
# DETAIL:  Key (location_id)=(483) is not present in table "price_range".
#
# [SQL: INSERT INTO restaurant_location (location_id, restaurant_id, restaurant_address, city, country, latitude, longitude, postal_code, province) VALUES (%(location_id)s, %(restaurant_id)s, %(restaurant_address)s, %(city)s, %(country)s, %(latitude)s, %(longitude)s, %(postal_code)s, %(province)s)]
# [parameters: ({'location_id': 0, 'restaurant_id': 487, 'restaurant_address': 'Cascade Village Mall Across From Target', 'city': 'Bend', 'country': 'US', 'latitude': 44.10266476, 'longitude': -121.3007971, 'postal_code': '97701', 'province': 'OR'}, {'location_id': 2, 'restaurant_id': 183, 'restaurant_address': '148 S Barrington Ave', 'city': 'Los Angeles', 'country': 'US', 'latitude': 34.06456347, 'longitude': -118.46901729999999, 'postal_code': '90049', 'province': 'Brentwood'}, {'location_id': 7, 'restaurant_id': 165, 'restaurant_address': '5142 Hollywood Blvd', 'city': 'Los Angeles', 'country': 'US', 'latitude': 34.1017424, 'longitude': -118.30197290000001, 'postal_code': '90027', 'province': 'Los Feliz'}, {'location_id': 13, 'restaurant_id': 844, 'restaurant_address': '801 Saint Emanuel St', 'city': 'Houston', 'country': 'US', 'latitude': 29.75247947, 'longitude': -95.35416442, 'postal_code': '77003', 'province': 'TX'}, {'location_id': 14, 'restaurant_id': 410, 'restaurant_address': '478 South St', 'city': 'Hyannis', 'country': 'US', 'latitude': 41.64827787, 'longitude': -70.29134463, 'postal_code': '2601', 'province': 'MA'}, {'location_id': 16, 'restaurant_id': 246, 'restaurant_address': '1 N University Hl', 'city': 'Provo', 'country': 'US', 'latitude': 40.25083927, 'longitude': -111.64926770000001, 'postal_code': '84602', 'province': 'UT'}, {'location_id': 20, 'restaurant_id': 797, 'restaurant_address': '9595 Six Pines Dr', 'city': 'Spring', 'country': 'US', 'latitude': 30.16413, 'longitude': -95.46235, 'postal_code': '77380', 'province': 'TX'}, {'location_id': 21, 'restaurant_id': 257, 'restaurant_address': '200 E Chestnut St', 'city': 'Chicago', 'country': 'US', 'latitude': 41.89854289, 'longitude': -87.6219955, 'postal_code': '60611', 'province': 'Ontario Street'}  ... displaying 10 of 981 total bound parameter sets ...  {'location_id': 3507, 'restaurant_id': 398, 'restaurant_address': '4140 Carlisle Rd', 'city': 'Dover', 'country': 'US', 'latitude': 39.996444, 'longitude': -76.8451799, 'postal_code': '17315', 'province': 'Davidsburg'}, {'location_id': 3509, 'restaurant_id': 875, 'restaurant_address': '9563 Kings Charter Doctor B', 'city': 'Ashland', 'country': 'US', 'latitude': 37.69316, 'longitude': -77.43744000000001, 'postal_code': '23005', 'province': 'VA'})]
# (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UniqueViolation: duplicate key value violates unique constraint "price_range_restaurant_name_key"
# DETAIL:  Key (restaurant_name)=(Larosa's Pizzeria) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-23-12c05d10b9e4> in <module>
# ----> 1 price_range_df.to_sql(name='price_range', con=engine, if_exists='append', index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1318         )
#    1319         table.create()
# -> 1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#    1322             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     754
#     755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 756                 exec_insert(conn, keys, chunk_iter)
#     757
#     758     def _query_iterator(
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         """
#     669         data = [dict(zip(keys, row)) for row in data_iter]
# --> 670         conn.execute(self.table.insert(), data)
#     671
#     672     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                 if not evt_handled:
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#    1231             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "price_range_restaurant_name_key"
# DETAIL:  Key (restaurant_name)=(Larosa's Pizzeria) already exists.
#
# [SQL: INSERT INTO price_range (restaurant_id, restaurant_name, price_range_min, price_range_max) VALUES (%(restaurant_id)s, %(restaurant_name)s, %(price_range_min)s, %(price_range_max)s)]
# [parameters: ({'restaurant_id': 0, 'restaurant_name': 'Little Pizza Paradise', 'price_range_min': '0', 'price_range_max': '0'}, {'restaurant_id': 2, 'restaurant_name': 'The Brentwood', 'price_range_min': 50.0, 'price_range_max': 55.0}, {'restaurant_id': 7, 'restaurant_name': 'Bravo Pizza Hollywood', 'price_range_min': '0', 'price_range_max': '0'}, {'restaurant_id': 13, 'restaurant_name': "Lucky's Pub", 'price_range_min': 25.0, 'price_range_max': 40.0}, {'restaurant_id': 14, 'restaurant_name': 'Roadhouse Cafe', 'price_range_min': '0', 'price_range_max': '0'}, {'restaurant_id': 16, 'restaurant_name': 'Brigham Young University', 'price_range_min': '0', 'price_range_max': '0'}, {'restaurant_id': 20, 'restaurant_name': "Luke's Locker", 'price_range_min': 0.0, 'price_range_max': 25.0}, {'restaurant_id': 21, 'restaurant_name': "Francesca's On Chestnut", 'price_range_min': 25.0, 'price_range_max': 40.0}  ... displaying 10 of 937 total bound parameter sets ...  {'restaurant_id': 3507, 'restaurant_name': 'Moonlight Cafe', 'price_range_min': 0.0, 'price_range_max': 30.0}, {'restaurant_id': 3509, 'restaurant_name': 'Guidos', 'price_range_min': 0.0, 'price_range_max': 30.0})]
# (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
pd.read_sql("Select * from price_range", con=engine)
# Out:
#      restaurant_id                    restaurant_name  price_range_min  \
# 0                0              Little Pizza Paradise              0.0
# 1                2                      The Brentwood             50.0
# 2                7              Bravo Pizza Hollywood              0.0
# 3               13                        Lucky's Pub             25.0
# 4               14                     Roadhouse Cafe              0.0
# ..             ...                                ...              ...
# 932           3498                     Rick's Cabaret              0.0
# 933           3499           Mighty Mick's Pub & Cafe              0.0
# 934           3500  Prison Brews Brewery & Restaurant             25.0
# 935           3507                     Moonlight Cafe              0.0
# 936           3509                             Guidos              0.0
#
#      price_range_max
# 0                0.0
# 1               55.0
# 2                0.0
# 3               40.0
# 4                0.0
# ..               ...
# 932              0.0
# 933              0.0
# 934             40.0
# 935             30.0
# 936             30.0
#
# [937 rows x 4 columns]
